# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# |Left  |Center|Right|
# |:-----|:----:|:----|
# |1     |A     |C    |
# |2     |B     |D    |
#
# <h1><div align="center"> CENTER </div></h1>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# This is testing a fraction.
#
# $$ \frac{3}{8} $$
#
# This is testing another fraction.
#
# $$ \frac{2}{3} $$

# %%
w = np.linspace(0, 20, 200)
plt.plot(w, np.sin(w))       # Plot the sine of each x point
plt.show()                   # Display the plot

# %%
$\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $



This is a test $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $ of putting an equation in-line with text.
# Out:
#   File "<ipython-input-3-b6f899aa9c67>", line 1
#     $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # A NEW Heading
#
# This is the time for all good men to come to the aid of their country.
# This is the time for all good men to come to the aid of their country.
# This is the time for all good men to come to the aid of their country.
# This is the time for all good men to come to the aid of their country.
# This is the time for all good men to come to the aid of their country.
# This is the time for all good men to come to the aid of their country.
#
#
#
# This is the time for all good men to come to the aid of their country. This is the time for all good men to come to the aid of their country. This is the time for all good men to come to the aid of their country. This is the time for all good men to come to the aid of their country. This is the time for all good men to come to the aid of their country. This is the time for all good men to come to the aid of their country.

# %%
w = np.linspace(10, 40, 400)
plt.plot(w, np.sin(w))       # Plot the sine of each x point
plt.show()                   # Display the plot

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(w, np.sin(w))       # Plot the sine of each x point
plt.show()                   # Display the plot

# %%
w = np.linspace(10, 40, 400)
plt.plot(w, 5*np.sin(w))       # Plot the sine of each x point
plt.show()                   # Display the plot

# %% [markdown]
# <blockquote>
# <p>some text</p>
# <blockquote>
# <p>and then some more text</p>
# <blockquote>
# <p>and then some more</p>
# </blockquote>
# </blockquote>
# </blockquote>

# %% [markdown]
#   $$e^{x+y}=e^xe^y$$
